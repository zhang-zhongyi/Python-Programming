# %% [markdown]
# # SciPy examples

# %%
# %pylab inline
import scipy
import matplotlib.pyplot as plt
import scipy.stats as ss
import numpy as np

import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Opening and writing to image files

# %%
from scipy import misc
f = misc.face()
misc.imsave('face.png', f) # uses the Image module (PIL)

plt.imshow(f)
plt.show()

# %% [markdown]
# ### Creating a numpy array from an image file:

# %%
type(f)
# Out:
# numpy.ndarray

# %%
f.shape, f.dtype
# Out:
# ((768, 1024, 3), dtype('uint8'))

# %% [markdown]
# ### Opening raw files

# %%
f.tofile('face.raw') # Create raw file
face_from_raw = np.fromfile('face.raw', dtype=np.uint8)
face_from_raw.shape
# Out:
# (2359296,)

# %%
face_from_raw.shape = (768, 1024, 3)

# %%
# for large data files
face_memmap = np.memmap('face.raw', dtype=np.uint8, shape=(768, 1024, 3))

# %%
plt.imshow(f)
plt.show()

# %% [markdown]
# ### Displaying image files

# %%
f = misc.face(gray=True)  # retrieve a grayscale image
plt.imshow(f, cmap=plt.cm.gray)

# %%
plt.imshow(f, cmap=plt.cm.gray, vmin=30, vmax=200)

# %%
plt.contour(f, [50, 200])

# %% [markdown]
# ## Image manipulation

# %%
face = misc.face(gray=True)
face[0, 40]
# Out:
# 127

# %%
# Slicing
face[10:13, 20:23]
# Out:
# array([[141, 153, 145],
#        [133, 134, 125],
#        [ 96,  92,  94]], dtype=uint8)

# %%
face = scipy.misc.face(gray=True)
face[10:13, 20:23]
face[100:120] = 255

lx, ly = face.shape
X, Y = np.ogrid[0:lx, 0:ly]
mask = (X - lx/2)**2 + (Y - ly/2)**2 > lx*ly/4
face[mask] = 0
face[range(400), range(400)] = 255

plt.figure(figsize=(3, 3))
plt.axes([0, 0, 1, 1])
plt.imshow(face, cmap=plt.cm.gray)
plt.axis('off')

plt.show()

# %% [markdown]
# ### Blurring/smoothing

# %%
from scipy import ndimage

f = scipy.misc.face(gray=True).astype(float)
blurred_f = ndimage.gaussian_filter(f, 3)

filter_blurred_f = ndimage.gaussian_filter(blurred_f, 1)

alpha = 30
sharpened = blurred_f + alpha * (blurred_f - filter_blurred_f)

plt.figure(figsize=(12, 4))

plt.subplot(131)
plt.imshow(f, cmap=plt.cm.gray)
plt.axis('off')
plt.subplot(132)
plt.imshow(blurred_f, cmap=plt.cm.gray)
plt.axis('off')
plt.subplot(133)
plt.imshow(sharpened, cmap=plt.cm.gray)
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Other examples

# %% [markdown]
# ### Optimization

# %%
from scipy import optimize
def f(x):
    return x**2 + 10*np.sin(x)

x = np.arange(-10, 10, 0.1)
plt.plot(x, f(x))
plt.show()

# %%
optimize.fmin_bfgs(f, 0)
# Out:
# Optimization terminated successfully.
#          Current function value: -7.945823
#          Iterations: 5
#          Function evaluations: 18
#          Gradient evaluations: 6
# array([-1.30644012])

# %%
optimize.fmin_bfgs(f, 3, disp=0)
# Out:
# array([ 3.83746709])

# %%
optimize.basinhopping(f, 0)
# Out:
#                         fun: -7.9458233756152845
#  lowest_optimization_result:       fun: -7.9458233756152845
#  hess_inv: array([[ 0.08580866]])
#       jac: array([  1.19209290e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 15
#       nit: 3
#      njev: 5
#    status: 0
#   success: True
#         x: array([-1.30644001])
#                     message: ['requested number of basinhopping iterations completed successfully']
#       minimization_failures: 0
#                        nfev: 1530
#                         nit: 100
#                        njev: 510
#                           x: array([-1.30644001])

# %%
x = np.linspace(-25,100,200)
myrv = ss.norm(loc=5, scale=10)
fx = myrv.pdf(x)
rvs = myrv.rvs(size=1000)

# %%
xmin_local = optimize.fminbound(f, 0, 10)
xmin_local
# Out:
# 3.8374671194983834

# %% [markdown]
# ### Finding roots

# %%
root = optimize.fsolve(f, 1) # our initial guess is 1
root
# Out:
# array([ 0.])

# %% [markdown]
# ### Curve Fitting

# %%
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a * np.exp(-b * x) + c

# %%
# define the data to be fit with some noise
xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
y_noise = 0.2 * np.random.normal(size=xdata.size)
ydata = y + y_noise
plt.plot(xdata, ydata, 'b-', label='data')

# %%
# fit for params a,b,c
popt, pcov = curve_fit(func, xdata, ydata)
plt.plot(xdata, func(xdata, *popt), 'r-', label='fit')

# Constrain the optimization to the region of ``0 < a < 3``, ``0 < b < 2`` and ``0 < c < 1``:
popt, pcov = curve_fit(func, xdata, ydata, bounds=(0, [3., 2., 1.]))

plt.plot(xdata, func(xdata, *popt), 'g--', label='fit-with-bounds')
plt.plot(xdata, ydata, 'b-', label='data')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ### Histograms

# %%
hist(rvs,bins=60, normed=True)
plt.plot(x,fx)

# %%
myrv.stats('mvks')
# Out:
# (array(5.0), array(100.0), array(0.0), array(0.0))

# %% [markdown]
# ### Linear Algebra

# %%
import scipy.linalg as linalg

# %%
scipy.linalg?

# %%
a = random.randn(10,10)
A = mat(a)
x = linspace(0, 1, 100)
y = where(x<0.8, 0, (x-0.8)**1.5)
yn = y + np.random.randn(len(x))*0.005
plot(x,y,x,yn,'ro');

# %%
import scipy.optimize as optimize

def myfunc(x, power, shift):
    return where(x < shift, 0, (x-shift)**power)

popt, pcov = optimize.curve_fit(myfunc, x, yn, p0=(1, 0.75))
errs = np.sqrt(np.diag(pcov))
popt_up = popt + errs
popt_down = popt - errs

# %%
plot(x,myfunc(x,*popt),x,myfunc(x,*popt_up),x,myfunc(x,*popt_down),x,yn,'ro');

# %%
from scipy.interpolate import Rbf
from scipy.special import j1
x,y = mgrid[-5:5:15j, -5:5:15j]
data = j1(np.hypot(x,y))
imshow(data,interpolation='none')

# %%
interpolated_func = Rbf(x,y,data,function='cubic')

xnew, ynew = mgrid[-5:5:50j,-5:5:50j]
newdata = interpolated_func(xnew, ynew)

imshow(newdata, interpolation='none')

# %%
x = linspace(-5,5,15)
y = j1(x)
    
plot(x,y,'ro');

# %%
import scipy.interpolate as interp

new = interp.interp1d(x,y,'cubic')
new2 = Rbf(x,y)

xp = linspace(-5,5,100)

plot(x,y,'ro',xp,new(xp), xp, new2(xp));

# %%
plot(xp, j1(xp)-new(xp), xp, j1(xp)-new2(xp))
legend(['cubic','Rbf'])

# %%
imshow(newdata.reshape(50,50),interpolation='none')
